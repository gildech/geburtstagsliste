# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from fuzzywuzzy import fuzz, process

# Importieren der Excel-Datei (sie liegt im gleichen Ordner wie dieses Notebook)
geburtstag = "Geburstage_2026.xlsx"

df = pd.read_excel(geburtstag, engine="openpyxl")

# %%
df.head(20)
# Out:
#                                              Kontakte  \
# 0    Adaastra Boutique Hotel (Imhof, Christian Frank)
# 1              Adler Gersau GmbH (Schadowske, Volker)
# 2                              Aeschlimann, Hans-Jürg
# 3            Albergo Croce Bianca (Zanolari, Claudio)
# 4                         ANICO GmbH (Schmid, Nicole)
# 5                Antico Grotto Ticino (Raith, Odette)
# 6               Auberge Les Viviers (Flury, Valentin)
# 7   AZ Gastro AG Restaurant Burestube (Camenzind, ...
# 8                     AZ Gastronomie AG (Zaugg, Andy)
# 9            B&B Rose Kerns GmbH (della Torre, Bruno)
# 10                  Bahnhöfli Root (Sägesser, Walter)
# 11                                   Barblan, Gaudenz
# 12              Bären Utzenstorf AG (Thommen, Martin)
# 13                                       Beer, Markus
# 14             Belvédère Scuol AG (Baumgartner, Kurt)
# 15             Berggasthaus Crest‘ Ota (Auchter, Urs)
# 16     Berggasthaus Niederbauen (Ineichen, Christine)
# 17      Bergrestaurant Moosalp (Kalbermatten, Amédée)
# 18         Bergrestaurant zum Roggen (Blaser, Martin)
# 19                        Bim buume (Baumann, Hannes)
#
#                                 Firma Anredeart          Vorname  \
# 0             Adaastra Boutique Hotel   Du-Form  Christian Frank
# 1                   Adler Gersau GmbH   Du-Form           Volker
# 2                                 NaN  Sie-Form        Hans-Jürg
# 3                Albergo Croce Bianca   Du-Form          Claudio
# 4                          ANICO GmbH   Du-Form           Nicole
# 5                Antico Grotto Ticino  Sie-Form           Odette
# 6                 Auberge Les Viviers   Du-Form         Valentin
# 7   AZ Gastro AG Restaurant Burestube   Du-Form             Rita
# 8                   AZ Gastronomie AG  Sie-Form             Andy
# 9                 B&B Rose Kerns GmbH   Du-Form            Bruno
# 10                     Bahnhöfli Root   Du-Form           Walter
# 11                                NaN  Sie-Form          Gaudenz
# 12                Bären Utzenstorf AG   Du-Form           Martin
# 13                                NaN   Du-Form           Markus
# 14                 Belvédère Scuol AG   Du-Form             Kurt
# 15            Berggasthaus Crest‘ Ota   Du-Form              Urs
# 16           Berggasthaus Niederbauen   Du-Form        Christine
# 17             Bergrestaurant Moosalp   Du-Form           Amédée
# 18          Bergrestaurant zum Roggen   Du-Form           Martin
# 19                          Bim buume  Sie-Form           Hannes
#
#         Nachname                     Strasse (Korr.) PLZ (Korr.)  \
# 0          Imhof                     Furkastrasse 16        3904
# 1     Schadowske                      Dorfstrasse 11        6442
# 2    Aeschlimann                      Oberi Chros 18        2513
# 3       Zanolari  Via da Mez 97\nCasella postale 135        7742
# 4         Schmid                     Untere Steig 15        8462
# 5          Raith                      Via Guiccio 15        6834
# 6          Flury                Route de Develier 24        2800
# 7      Camenzind                       Bachstrasse 3        5033
# 8          Zaugg                    Friedhofplatz 10        4500
# 9    della Torre                       Dorfstrasse 5        6064
# 10      Sägesser                   Bahnhofstrasse 42        6037
# 11       Barblan           Äussere Bahnhofstrasse 19        7250
# 12       Thommen                     Hauptstrasse 18        3427
# 13          Beer            Voia Tgaplotta dameaz 34        7492
# 14   Baumgartner                         Stardun 330        7550
# 15       Auchter                    Dieschen seura 7        7078
# 16      Ineichen                       Niederbauen 1        6376
# 17  Kalbermatten                  Moosalpstrasse 357        3929
# 18        Blaser                            Roggen 1        4702
# 19       Baumann                Unterwasserstrasse 6        6260
#
#          Ort (Korr.) Geburtsdatum Korresp.sprache       Mitgliedschaft
# 0             Naters   06.08.1970         Deutsch                Aktiv
# 1             Gersau   06.05.1970         Deutsch                Aktiv
# 2              Twann   20.01.1949         Deutsch               Passiv
# 3          Poschiavo   28.03.1974         Deutsch                Aktiv
# 4            Rheinau   18.12.1993         Deutsch                Aktiv
# 5   Morbio Inferiore   30.08.1956         Deutsch  Antrag Aktiv-Passiv
# 6           Delémont   17.02.1963     Französisch                Aktiv
# 7              Buchs   19.03.1975         Deutsch                Aktiv
# 8          Solothurn   21.06.1966         Deutsch               Passiv
# 9              Kerns   11.09.1980         Deutsch                Aktiv
# 10              Root   17.03.1960         Deutsch                Aktiv
# 11          Klosters   29.04.1946         Deutsch               Passiv
# 12        Utzenstorf   20.01.1980         Deutsch                Aktiv
# 13      Alvaneu Dorf   13.08.1948         Deutsch               Passiv
# 14             Scuol   17.09.1965         Deutsch                Aktiv
# 15       Lenzerheide   09.08.1983         Deutsch                Aktiv
# 16          Emmetten   04.06.1982         Deutsch                Aktiv
# 17            Törbel   17.11.1966         Deutsch                Aktiv
# 18         Oensingen   19.01.1983         Deutsch                Aktiv
# 19            Reiden   18.08.1960         Deutsch               Passiv

# %%
# Die Spalte 'Geburtstag' wird in das Datetime-Format konvertiert (Monat/Tag ignoriert Jahr, wenn angegeben)
df['Geburtsdatum'] = pd.to_datetime(df['Geburtsdatum'], errors='coerce', dayfirst=True)

# Hilfsspalte für Sortierung nach Monat und Tag
df['_geburtstag_sort'] = df['Geburtsdatum'].dt.strftime('%m-%d')

# Sortiere DataFrame vom 01.01. bis 31.12.
df = df.sort_values('_geburtstag_sort').reset_index(drop=True)

# Hilfsspalte wieder entfernen
df = df.drop('_geburtstag_sort', axis=1)

# %%
df.head(20)
# Out:
#                                              Kontakte  \
# 0                          Werner Rätz (Rätz, Werner)
# 1                                     Chicherio, Remo
# 2                                      Kaufmann, René
# 3             Landgasthof Seelust AG (Hasen, Mattias)
# 4                                    Riedener, Thomas
# 5    Hotel Waldsägmühle GmbH &Co.KG (Ziegler, Martin)
# 6   Restaurant Bahnhöfli Entlebuch AG (Felder, Willi)
# 7                               Birchmeier, Christian
# 8                      Hotel al ponte (Walker, Frank)
# 9                 Hotel Frohe Aussicht (Inauen, Arno)
# 10                                       Kempf, Alois
# 11    Landgasthof Löwen Sulgen AG (Fritschi, Patrick)
# 12                     Rössli Illnau (Hoffer, Rainer)
# 13         Grunders Buechwäldli AG (Grunder, Patrick)
# 14             Restaurant Mont-Rouge (Lathion, Loris)
# 15                   Restaurant Rose (Knöpfel, Peter)
# 16         Bergrestaurant zum Roggen (Blaser, Martin)
# 17              Bären Utzenstorf AG (Thommen, Martin)
# 18                                        Darms, Toni
# 19                             Aeschlimann, Hans-Jürg
#
#                                 Firma Anredeart    Vorname     Nachname  \
# 0                         Werner Rätz   Du-Form     Werner         Rätz
# 1                                 NaN  Sie-Form       Remo    Chicherio
# 2                                 NaN   Du-Form       René     Kaufmann
# 3              Landgasthof Seelust AG   Du-Form    Mattias        Hasen
# 4                                 NaN  Sie-Form     Thomas     Riedener
# 5      Hotel Waldsägmühle GmbH &Co.KG   Du-Form     Martin      Ziegler
# 6   Restaurant Bahnhöfli Entlebuch AG   Du-Form      Willi       Felder
# 7                                 NaN   Du-Form  Christian   Birchmeier
# 8                      Hotel al ponte   Du-Form      Frank       Walker
# 9                Hotel Frohe Aussicht   Du-Form       Arno       Inauen
# 10                                NaN   Du-Form      Alois        Kempf
# 11        Landgasthof Löwen Sulgen AG   Du-Form    Patrick     Fritschi
# 12                      Rössli Illnau   Du-Form     Rainer       Hoffer
# 13            Grunders Buechwäldli AG   Du-Form    Patrick      Grunder
# 14              Restaurant Mont-Rouge  Sie-Form      Loris      Lathion
# 15                    Restaurant Rose   Du-Form      Peter      Knöpfel
# 16          Bergrestaurant zum Roggen   Du-Form     Martin       Blaser
# 17                Bären Utzenstorf AG   Du-Form     Martin      Thommen
# 18                                NaN   Du-Form       Toni        Darms
# 19                                NaN  Sie-Form  Hans-Jürg  Aeschlimann
#
#                Strasse (Korr.) PLZ (Korr.)                    Ort (Korr.)  \
# 0                  Moosgasse 5        3215                       Büchslen
# 1          Schlüsselmattweg 12        8840                     Einsiedeln
# 2                 Neubrunn 823        8488                     Turbenthal
# 3                    Wiedehorn        9322                         Egnach
# 4                  Silserweg 4        7430                         Thusis
# 5              Waldsägemühle 1     D-72285  Pfalzgrafenweiler-Kälberbronn
# 6            Bahnhofstrasse 30        6162                      Entlebuch
# 7   Fanenrietstrasse 1\nHaus A        7320                        Sargans
# 8             Wangenstrasse 55        3380             Wangen an der Aare
# 9                Küchenrain 11        9057                       Schwende
# 10              Poststrasse 41        7000                           Chur
# 11             Hauptstrasse 27        8583                         Sulgen
# 12          Kempttalstrasse 52        8308                         Illnau
# 13         Hauptseestrasse 131        6315                      Morgarten
# 14        Rte de la Télécabine        1997                   Haute-Nendaz
# 15            Gontenstrasse 35        9050                      Appenzell
# 16                    Roggen 1        4702                      Oensingen
# 17             Hauptstrasse 18        3427                     Utzenstorf
# 18            Valserstrasse 18        7130                          Ilanz
# 19              Oberi Chros 18        2513                          Twann
#
#    Geburtsdatum Korresp.sprache   Mitgliedschaft
# 0    1959-01-01         Deutsch           Passiv
# 1    1979-01-01         Deutsch           Passiv
# 2    1962-01-02         Deutsch    Ehrenmitglied
# 3    1984-01-03         Deutsch            Aktiv
# 4    1965-01-03         Deutsch  Passiv Austritt
# 5    1970-01-04         Deutsch            Aktiv
# 6    1986-01-05         Deutsch            Aktiv
# 7    1969-01-06         Deutsch    Ehrenmitglied
# 8    1972-01-07         Deutsch            Aktiv
# 9    1975-01-07         Deutsch            Aktiv
# 10   1948-01-08         Deutsch    Ehrenmitglied
# 11   1989-01-08         Deutsch            Aktiv
# 12   1973-01-09         Deutsch            Aktiv
# 13   1970-01-13         Deutsch            Aktiv
# 14   1977-01-14     Französisch            Aktiv
# 15   1986-01-16         Deutsch            Aktiv
# 16   1983-01-19         Deutsch            Aktiv
# 17   1980-01-20         Deutsch            Aktiv
# 18   1954-01-20         Deutsch    Ehrenmitglied
# 19   1949-01-20         Deutsch           Passiv

# %%
df.drop(columns=['Kontakte', 'Anredeart'], inplace=True)

# Benenne die Spalten 'Strasse (Korr.)', 'PLZ (Korr.)', 'Ort (Korr.)' um (entferne ' (Korr.)')
df = df.rename(columns={
    'Strasse (Korr.)': 'Strasse',
    'PLZ (Korr.)': 'PLZ',
    'Ort (Korr.)': 'Ort'
})

df.head(20)
# Out:
#                                 Firma    Vorname     Nachname  \
# 0                         Werner Rätz     Werner         Rätz
# 1                                 NaN       Remo    Chicherio
# 2                                 NaN       René     Kaufmann
# 3              Landgasthof Seelust AG    Mattias        Hasen
# 4                                 NaN     Thomas     Riedener
# 5      Hotel Waldsägmühle GmbH &Co.KG     Martin      Ziegler
# 6   Restaurant Bahnhöfli Entlebuch AG      Willi       Felder
# 7                                 NaN  Christian   Birchmeier
# 8                      Hotel al ponte      Frank       Walker
# 9                Hotel Frohe Aussicht       Arno       Inauen
# 10                                NaN      Alois        Kempf
# 11        Landgasthof Löwen Sulgen AG    Patrick     Fritschi
# 12                      Rössli Illnau     Rainer       Hoffer
# 13            Grunders Buechwäldli AG    Patrick      Grunder
# 14              Restaurant Mont-Rouge      Loris      Lathion
# 15                    Restaurant Rose      Peter      Knöpfel
# 16          Bergrestaurant zum Roggen     Martin       Blaser
# 17                Bären Utzenstorf AG     Martin      Thommen
# 18                                NaN       Toni        Darms
# 19                                NaN  Hans-Jürg  Aeschlimann
#
#                        Strasse      PLZ                            Ort  \
# 0                  Moosgasse 5     3215                       Büchslen
# 1          Schlüsselmattweg 12     8840                     Einsiedeln
# 2                 Neubrunn 823     8488                     Turbenthal
# 3                    Wiedehorn     9322                         Egnach
# 4                  Silserweg 4     7430                         Thusis
# 5              Waldsägemühle 1  D-72285  Pfalzgrafenweiler-Kälberbronn
# 6            Bahnhofstrasse 30     6162                      Entlebuch
# 7   Fanenrietstrasse 1\nHaus A     7320                        Sargans
# 8             Wangenstrasse 55     3380             Wangen an der Aare
# 9                Küchenrain 11     9057                       Schwende
# 10              Poststrasse 41     7000                           Chur
# 11             Hauptstrasse 27     8583                         Sulgen
# 12          Kempttalstrasse 52     8308                         Illnau
# 13         Hauptseestrasse 131     6315                      Morgarten
# 14        Rte de la Télécabine     1997                   Haute-Nendaz
# 15            Gontenstrasse 35     9050                      Appenzell
# 16                    Roggen 1     4702                      Oensingen
# 17             Hauptstrasse 18     3427                     Utzenstorf
# 18            Valserstrasse 18     7130                          Ilanz
# 19              Oberi Chros 18     2513                          Twann
#
#    Geburtsdatum Korresp.sprache   Mitgliedschaft
# 0    1959-01-01         Deutsch           Passiv
# 1    1979-01-01         Deutsch           Passiv
# 2    1962-01-02         Deutsch    Ehrenmitglied
# 3    1984-01-03         Deutsch            Aktiv
# 4    1965-01-03         Deutsch  Passiv Austritt
# 5    1970-01-04         Deutsch            Aktiv
# 6    1986-01-05         Deutsch            Aktiv
# 7    1969-01-06         Deutsch    Ehrenmitglied
# 8    1972-01-07         Deutsch            Aktiv
# 9    1975-01-07         Deutsch            Aktiv
# 10   1948-01-08         Deutsch    Ehrenmitglied
# 11   1989-01-08         Deutsch            Aktiv
# 12   1973-01-09         Deutsch            Aktiv
# 13   1970-01-13         Deutsch            Aktiv
# 14   1977-01-14     Französisch            Aktiv
# 15   1986-01-16         Deutsch            Aktiv
# 16   1983-01-19         Deutsch            Aktiv
# 17   1980-01-20         Deutsch            Aktiv
# 18   1954-01-20         Deutsch    Ehrenmitglied
# 19   1949-01-20         Deutsch           Passiv

# %%
# Füge eine neue Spalte 'Alter 2026' hinzu, die berechnet, wie alt die Person an ihrem Geburtstag im Jahr 2026 wird
df['Alter 2026'] = 2026 - df['Geburtsdatum'].dt.year

df.sample(20)
# Out:
#                            Firma    Vorname         Nachname  \
# 207      Restaurant Stiva Veglia       Tino       Zimmermann
# 289                          NaN  Christian          Jurczyk
# 202        Gasthof Adler Sempach  Hanspeter           Künzli
# 196                          NaN     Dieter             Roth
# 267              Marco Putschert      Marco       Purtschert
# 162    Panorama Genussmanufaktur     Daniel     Rindisbacher
# 303                  Thurberg AG     Daniel            Franz
# 340                          NaN       Rolf       Schumacher
# 137   Gasthaus zum Kantonsschild      Fritz  Leicht-Flühmann
# 128                          NaN      Josef         Pelzmann
# 84           Wirtshus zum Wyberg     Martin      Aeschlimann
# 164            AZ Gastronomie AG       Andy            Zaugg
# 31                           NaN      Jakob            Huber
# 176               Gasthaus Löwen    Philipp           Zettel
# 11   Landgasthof Löwen Sulgen AG    Patrick         Fritschi
# 30     Restaurant Hohliebestübli       Andy          Schranz
# 93      Restaurant Der Schwiizer   Vittorio        Laubscher
# 331          Hotel Alpina Parpan     Markus         Beckmann
# 308                  Zum Sternen     Adrian            Meier
# 149        Restaurant Muggenbühl      Ernst         Bachmann
#
#                    Strasse   PLZ                         Ort Geburtsdatum  \
# 207            Via Vitg 51  7130                     Schnaus   1975-08-21
# 289        Via Maistra 128  7505         Celerina-St. Moritz   1949-11-07
# 202        Stadtstrasse 22  6204                     Sempach   1963-08-19
# 196           Badhübel 348  5728                Gontenschwil   1947-08-11
# 267           Beim Kreuz 7  4800          Langnau bei Reiden   1969-10-18
# 162   Aeschiriedstrasse 36  3703  Aeschi ob Spiez/Aeschiried   1961-06-21
# 303     Thurbergstrasse 29  8570                  Weinfelden   1958-11-20
# 340          Rüfistrasse 6  7076                      Parpan   1955-12-25
# 137        Hauptstrasse 24  3215                   Gempenach   1960-05-25
# 128              Burgweg 3  3294           Büren an der Aare   1945-05-18
# 84   Oberteufenerstrasse 1  8428          Freienstein-Teufen   1987-03-24
# 164       Friedhofplatz 10  4500                   Solothurn   1966-06-21
# 31          Bachstrasse 31  8427                      Rorbas   1961-02-08
# 176    Sandgrubenstrasse 1  6146                Grossdietwil   1972-07-22
# 11         Hauptstrasse 27  8583                      Sulgen   1989-01-08
# 30          Hohliebeweg 17  3715                   Adelboden   1972-02-08
# 93           Dorfstrasse 2  3908                  Saas-Balen   1959-04-03
# 331        Hauptstrasse 33  7076                      Parpan   1986-12-17
# 308      Endingerstrasse 7  5303                 Würenlingen   1965-11-23
# 149   Muggenbühlstrasse 15  8038          Zürich-Wollishofen   1946-06-09
#
#     Korresp.sprache Mitgliedschaft  Alter 2026
# 207         Deutsch          Aktiv        51.0
# 289         Deutsch         Passiv        77.0
# 202         Deutsch          Aktiv        63.0
# 196         Deutsch         Passiv        79.0
# 267         Deutsch         Passiv        57.0
# 162         Deutsch  Ehrenmitglied        65.0
# 303         Deutsch          Aktiv        68.0
# 340         Deutsch         Passiv        71.0
# 137         Deutsch          Aktiv        66.0
# 128         Deutsch         Passiv        81.0
# 84          Deutsch          Aktiv        39.0
# 164         Deutsch         Passiv        60.0
# 31          Deutsch  Ehrenmitglied        65.0
# 176         Deutsch          Aktiv        54.0
# 11          Deutsch          Aktiv        37.0
# 30          Deutsch          Aktiv        54.0
# 93          Deutsch          Aktiv        67.0
# 331         Deutsch          Aktiv        40.0
# 308         Deutsch          Aktiv        61.0
# 149         Deutsch          Aktiv        80.0

# %%
import pandas as pd
import numpy as np

# ExcelWriter erstellen
with pd.ExcelWriter('Geburtstagsliste_2026.xlsx', engine='xlsxwriter') as writer:
    # Erstelle zusätzliche Spalten falls noch nicht vorhanden
    df['Monat'] = df['Geburtsdatum'].dt.month
    df['Tag'] = df['Geburtsdatum'].dt.day

    # Name des Monats für das Tabellensheet (in Deutsch)
    monat_namen = {
        1: 'Januar', 2: 'Februar', 3: 'März', 4: 'April',
        5: 'Mai', 6: 'Juni', 7: 'Juli', 8: 'August',
        9: 'September', 10: 'Oktober', 11: 'November', 12: 'Dezember'
    }

    # Aufteilung nach Monaten
    for monat in range(1, 13):
        df_monat = df[df['Monat'] == monat].copy()
        if df_monat.empty:
            continue

        # Sortiere nach Tag
        df_monat = df_monat.sort_values('Tag')

        # Anzeigeformat für Geburtsdatum als 'dd.mm.yyyy'
        df_monat['Geburtsdatum (TT.MM.JJJJ)'] = df_monat['Geburtsdatum'].dt.strftime('%d.%m.%Y')

        # Füge Spalte 'Mitgliedschaft' hinzu (ggf. vorhandene Spalte nutzen)
        mitgliedschaft_col = None
        for mgl_col in ['Mitgliedschaft', 'mitgliedschaft', 'Mitglied', 'mitglied']:
            if mgl_col in df_monat.columns:
                mitgliedschaft_col = mgl_col
                break

        # Spaltenauswahl: Vorname, Nachname, Geburtsdatum (TT.MM.JJJJ), Firma, Strasse, PLZ, Ort, Alter 2026, Mitgliedschaft
        # Die Originalspalte "Geburtsdatum" NICHT übernehmen
        desired_cols = [
            'Vorname', 'Nachname', 'Geburtsdatum (TT.MM.JJJJ)',
            'Firma', 'Strasse', 'PLZ', 'Ort', 'Alter 2026'
        ]
        if mitgliedschaft_col:
            desired_cols.append(mitgliedschaft_col)
        # Nur existierende Spalten behalten
        sheet_cols = [c for c in desired_cols if c in df_monat.columns]
        export_df = df_monat[sheet_cols]

        # Schreibe DataFrame in Excel-Sheet
        sheet_name = monat_namen.get(monat, f"Monat_{monat}")
        export_df.to_excel(writer, sheet_name=sheet_name, index=False)

        # Zugriff aufs Sheet für Formatierungen
        workbook  = writer.book
        worksheet = writer.sheets[sheet_name]

        # Excel Formate definieren
        alter_format = workbook.add_format({'num_format': '0'})
        date_format_german = workbook.add_format({'num_format': 'dd.mm.yyyy'})
        green_highlight_format = workbook.add_format({'bg_color': '#C6EFCE', 'font_color': '#006100'}) # Excel Grün
        # Spezielles Hervorhebungsformat für Ehrenmitglied etc.
        yellow_highlight_format = workbook.add_format({'bg_color': '#FFF2CC', 'font_color': '#7F6000'})
        # Fettdruck für Header
        bold_format = workbook.add_format({'bold': True})
        worksheet.set_row(0, None, bold_format)
        # Spaltenbreiten setzen (Alle Spalten etwas schön machen)
        worksheet.set_column(0, len(sheet_cols)-1, 18)

        # Runde Geburtstage grün hervorheben
        if 'Alter 2026' in sheet_cols:
            alter_col_idx = sheet_cols.index('Alter 2026')
            col_letter = chr(ord('A') + alter_col_idx)
            row_end = len(export_df)
            rng = f'{col_letter}2:{col_letter}{row_end+1}'
            worksheet.conditional_format(
                rng,
                {
                    'type':     'formula',
                    'criteria': f'=AND(MOD({col_letter}2,10)=0,NOT(ISBLANK({col_letter}2)))',
                    'format':   green_highlight_format
                }
            )

        # Optional: Datumsformat für 'Geburtsdatum (TT.MM.JJJJ)'
        if 'Geburtsdatum (TT.MM.JJJJ)' in sheet_cols:
            geb_de_col_idx = sheet_cols.index('Geburtsdatum (TT.MM.JJJJ)')
            worksheet.set_column(geb_de_col_idx, geb_de_col_idx, 18, date_format_german)

        # EHRENMITGLIED- und weitere Rollenhervorhebung
        if mitgliedschaft_col and mitgliedschaft_col in sheet_cols:
            mg_col_idx = sheet_cols.index(mitgliedschaft_col)
            mg_col_letter = chr(ord('A') + mg_col_idx)
            row_end = len(export_df)
            # Formeln für die Hervorhebung Ehrenmitglied etc.
            for rolle in ["Ehrenmitglied", "Ehrenpräsident", "Prinzenrolle"]:
                worksheet.conditional_format(
                    f'A2:{chr(ord("A")+len(sheet_cols)-1)}{row_end+1}',
                    {
                        'type': 'formula',
                        'criteria': f'=ISNUMBER(SEARCH("{rolle}", ${mg_col_letter}2))',
                        'format': yellow_highlight_format
                    }
                )
    # Nach Monatsblättern: 'Ohne Geburtsdatum'-Sheet erstellen
    df_ohne_datum = df[df['Geburtsdatum'].isna()].copy()

    if not df_ohne_datum.empty:
        # Eventuell Mitgiedschaftsspalte wie oben suchen
        mitgliedschaft_col = None
        for mgl_col in ['Mitgliedschaft', 'mitgliedschaft', 'Mitglied', 'mitglied']:
            if mgl_col in df_ohne_datum.columns:
                mitgliedschaft_col = mgl_col
                break
        # Anzeigeformat-Spalte hinzufügen (wird leer bleiben)
        df_ohne_datum['Geburtsdatum (TT.MM.JJJJ)'] = ""
        # Gleiches Spaltenlayout wie bei den Monatsblättern
        desired_cols = [
            'Vorname', 'Nachname', 'Geburtsdatum (TT.MM.JJJJ)',
            'Firma', 'Strasse', 'PLZ', 'Ort', 'Alter 2026'
        ]
        if mitgliedschaft_col:
            desired_cols.append(mitgliedschaft_col)
        sheet_cols = [c for c in desired_cols if c in df_ohne_datum.columns]
        export_df_ohne = df_ohne_datum[sheet_cols]
        # Schreibe in ein weiteres Sheet nach Dezember
        export_df_ohne.to_excel(writer, sheet_name='Ohne Geburtsdatum', index=False)

        # Zugriff aufs Sheet für Formatierungen
        workbook  = writer.book
        worksheet = writer.sheets['Ohne Geburtsdatum']
        # Fettdruck für Header
        bold_format = workbook.add_format({'bold': True})
        worksheet.set_row(0, None, bold_format)
        worksheet.set_column(0, len(sheet_cols)-1, 18)

# Hinweis-Output für den User
print("Geburtstagsliste_2026.xlsx erfolgreich erstellt: Pro Monat ein Tabellenblatt, runde Geburtstage grün markiert, Ehrenmitglieder/-präsidenten/Prinzenrolle gelb hervorgehoben. Die Spalte 'Geburtsdatum' wird nur noch als TT.MM.JJJJ angezeigt, danach folgen Firma, Strasse, PLZ, Ort.")
print("Zusätzlicher Reiter 'Ohne Geburtsdatum' für alle Einträge ohne Datum hinzugefügt.")
# Out:
# Geburtstagsliste_2026.xlsx erfolgreich erstellt: Pro Monat ein Tabellenblatt, runde Geburtstage grün markiert, Ehrenmitglieder/-präsidenten/Prinzenrolle gelb hervorgehoben. Die Spalte 'Geburtsdatum' wird nur noch als TT.MM.JJJJ angezeigt, danach folgen Firma, Strasse, PLZ, Ort.

# %%
# Anzahl ausgegebener Namen, Geburtsdaten und fehlgeschlagene (fehlende) Geburtsdaten ausgeben
anzahl_namen = export_df['Vorname'].notna().sum()
anzahl_geburtsdaten = export_df['Geburtsdatum (TT.MM.JJJJ)'].notna().sum() if 'Geburtsdatum (TT.MM.JJJJ)' in export_df.columns else 0
anzahl_fehlende_geburtsdaten = export_df['Geburtsdatum (TT.MM.JJJJ)'].isna().sum() if 'Geburtsdatum (TT.MM.JJJJ)' in export_df.columns else len(export_df)

print(f"Anzahl Namen in der Liste: {anzahl_namen}")
print(f"Anzahl Geburtsdaten in der Liste: {anzahl_geburtsdaten}")
print(f"Fehlgeschlagene (fehlende) Geburtsdaten: {anzahl_fehlende_geburtsdaten}")
# Out:
# Anzahl Namen in der Liste: 33
# Anzahl Geburtsdaten in der Liste: 33
# Fehlgeschlagene (fehlende) Geburtsdaten: 0
